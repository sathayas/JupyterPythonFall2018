# %% [markdown]
# <p style="text-align:center">
# PSY 341K <b>Python Coding for Psychological Sciences</b>, Fall 2018
#
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png" alt="Python logo" width="200">
# </p>
#
# <h1 style="text-align:center"> Data frame with Pandas </h1>
#
# <h4 style="text-align:center"> November 15 - 27, 2018 </h4>
# <hr style="height:5px;border:none" />
# <p>

# %% [markdown]
# # 0. What is a dataframe?
# <hr style="height:1px;border:none" />

# %% [markdown]
# Say, you have a data set consisting of scores from the same subjects under 4 different conditions.

# %% [markdown]
# `<ExpScoreData.py>`

# %%
import numpy as np
import pandas as pd

# experiment data: Scores from
#    control condition:  control
#    condition A:        condA
#    condition B:        condB
#    condition C:        condC
control = np.array([106,  96,  79, 110,  87,  81,  83,  68,  79,  57])
condA = np.array([80, 70, 63, 73, 64, 78, 68, 45, 66, 56])
condB = np.array([ 78,  97, 120,  92,  84, 116,  81,  81, 104,  82])
condC = np.array([ 75,  49,  58, 115,  97,  95,  93,  66,  84,  67])

# %% [markdown]
# You can treat them as 4 separate arrays. Or, you can treat them as a part of a one big data set, known as a **dataframe**. To do so, you need to use the **`Pandas`** library (imported as **`pd`** for short).

# %%
# concatenating the variables
allData = np.vstack([control,condA,condB,condC]).T

# creating a dataframe
expScores = pd.DataFrame(allData, columns=['control','condA','condB','condC'])

# %%
expScores
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# Notice that, in a dataframe, each row consists of an observation with multiple values. Each column is a variable. If you are dealing with a large number of variables originating from the same individuals, it makes sense to handle that data set as a dataframe, as opposed to dealing with a number of separate arrays or lists.

# %% [markdown]
# # 1. How to create a dataframe
# <hr style="height:1px;border:none" />

# %% [markdown]
# You can create a dataframe from a 2D array, as presented earlier. Or, you can create an empty dataframe and add one column at a time.

# %% [markdown]
# `<FirstDataFrame.py>`

# %%
expData = pd.DataFrame()
expData['control'] = control
expData['condA'] = condA
expData['condB'] = condB
expData['condC'] = condC

# %%
expData
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# ### Exercise
# 1. **Creating a data frame**. The NumPy array data file [**`CryotherapyData.npz`**](https://github.com/sathayas/PythonClassFall2018/raw/master/pandasExamples/CryotherapyData.npz) on **GitHub** contains 4 arrays from a data set on cryotherapy outcomes from 90 patients. (You may recall this data set from Homework Assignment 4). The data arrays are:
#
#   * **`age`**: Age of the patient
#   * **`time`**: Time elapsed between the diagnosis and the treatment (months)
#   * **`area`**: Surface area of warts (mm<sup>2</sup>)
#   * **`success`**: Success in a cryotherapy, 1=yes, 0=no
#
# From these arrays, create a dataframe with these variables as columns.

# %% [markdown]
# # 2. Useful attributes and methods to examine a dataframe
# <hr style="height:1px;border:none" />

# %% [markdown]
# There are some useful attributes and methods associated with a dataframe. You can examine the first few observations in a dataframe with **`head()`** method.

# %%
expData.head()
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97

# %% [markdown]
# Similarly, you can examine the last few observations with **`tail()`** method.

# %%
expData.tail()
# Out:
#    control  condA  condB  condC
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# To get names of the columns, you can use **`columns`**.

# %%
expData.columns
# Out:
# Index(['control', 'condA', 'condB', 'condC'], dtype='object')

# %% [markdown]
# You can get some basic descriptive statistics for each column by using the **`describe()`** method.

# %%
expData.describe()
# Out:
#           control      condA       condB       condC
# count   10.000000  10.000000   10.000000   10.000000
# mean    84.600000  66.300000   93.500000   79.900000
# std     16.174053  10.339246   15.306135   20.436623
# min     57.000000  45.000000   78.000000   49.000000
# 25%     79.000000  63.250000   81.250000   66.250000
# 50%     82.000000  67.000000   88.000000   79.500000
# 75%     93.750000  72.250000  102.250000   94.500000
# max    110.000000  80.000000  120.000000  115.000000

# %% [markdown]
# You can sort the entire dataframe based on a variable using **`sort_values()`** method. For example, we can sort the data with the scores from variable `control` in ascending order.

# %%
expData.sort_values(by='control')
# Out:
#    control  condA  condB  condC
# 9       57     56     82     67
# 7       68     45     81     66
# 2       79     63    120     58
# 8       79     66    104     84
# 5       81     78    116     95
# 6       83     68     81     93
# 4       87     64     84     97
# 1       96     70     97     49
# 0      106     80     78     75
# 3      110     73     92    115

# %% [markdown]
# The variable `control` is sorted in the *ascending order* by default. You can sort in the *descending order* by specifying parameter **`ascending=False`**.

# %%
expData.sort_values(by='control', ascending=False)
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 0      106     80     78     75
# 1       96     70     97     49
# 4       87     64     84     97
# 6       83     68     81     93
# 5       81     78    116     95
# 2       79     63    120     58
# 8       79     66    104     84
# 7       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# This method does not alter the dataframe, so you need to do specify parameter **`inplace=True`**.

# %%
expData.sort_values(by='control', ascending=False, inplace=True)
expData
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 0      106     80     78     75
# 1       96     70     97     49
# 4       87     64     84     97
# 6       83     68     81     93
# 5       81     78    116     95
# 2       79     63    120     58
# 8       79     66    104     84
# 7       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# Notice that the dataframe has been updated.
#
# You can remove a column by **`drop()`** method. For example, to delete the variable **`condB`**, you can do

# %%
expData.drop('condB', axis=1)
# Out:
#    control  condA  condC
# 3      110     73    115
# 0      106     80     75
# 1       96     70     49
# 4       87     64     97
# 6       83     68     93
# 5       81     78     95
# 2       79     63     58
# 8       79     66     84
# 7       68     45     66
# 9       57     56     67

# %% [markdown]
# Here, **`axis=1`** indicates that we are deleting a column **`condB`**, and **`inplace=True`** specifies that we are making a change to the dataframe (omitted in this case).
#
#
# ### Exercise
# 1. From the dataframe you created earlier on the cryotherapy data, calculate summary statistics for each variable.
# 2. **Rank, area**. Add a new variable called **`rankArea`** to the dataframe, describing the the rank of `area` (from the largest to the smallest). You can rank tied observations arbitrarily (e.g., 750 and 750 may be ranked as 1 and 2, or 2 and 1; either is fine). ***Hint:*** *Sort the data frame according to `area` in the descending order (i.e., `ascending=False`). Then add a column of with a sequence of numbers from 1 to 90.*

# %% [markdown]
# # 3. Indexing and slicing a dataframe
# <hr style="height:1px;border:none" />

# %%
import numpy as np
import pandas as pd

# experiment data: Scores from
#    control condition:  control
#    condition A:        condA
#    condition B:        condB
#    condition C:        condC
control = np.array([106,  96,  79, 110,  87,  81,  83,  68,  79,  57])
condA = np.array([80, 70, 63, 73, 64, 78, 68, 45, 66, 56])
condB = np.array([ 78,  97, 120,  92,  84, 116,  81,  81, 104,  82])
condC = np.array([ 75,  49,  58, 115,  97,  95,  93,  66,  84,  67])

expData = pd.DataFrame()
expData['control'] = control
expData['condA'] = condA
expData['condB'] = condB
expData['condC'] = condC

expData.sort_values(by='control', ascending=False, inplace=True)

# %% [markdown]
# In a dataframe, you can access individual column (or variable) by

# %%
expData['condA']
# Out:
# 3    73
# 0    80
# 1    70
# 4    64
# 6    68
# 5    78
# 2    63
# 8    66
# 7    45
# 9    56
# Name: condA, dtype: int64

# %% [markdown]
# Or,

# %%
expData.condA
# Out:
# 3    73
# 0    80
# 1    70
# 4    64
# 6    68
# 5    78
# 2    63
# 8    66
# 7    45
# 9    56
# Name: condA, dtype: int64

# %% [markdown]
# You can slice rows in a dataframe very easily. For example,

# %%
expData[5:8]
# Out:
#    control  condA  condB  condC
# 5       81     78    116     95
# 2       79     63    120     58
# 8       79     66    104     84

# %% [markdown]
# You can slice rows with only a few selected variables only, using **`loc`** method.

# %%
expData.loc[5:8,['condA','condB']]
# Out:
#    condA  condB
# 5     78    116
# 2     63    120
# 8     66    104

# %% [markdown]
# Or, if you know the row and column indices, then you can use **`iloc`** method.

# %%
expData.iloc[5:8,1:3]
# Out:
#    condA  condB
# 5     78    116
# 2     63    120
# 8     66    104

# %% [markdown]
# And you can use the data itself to select a subset of data, like in arrays. For example,

# %%
expData[expData.control>100]
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 0      106     80     78     75

# %%
expData[expData.condA<expData.condC]
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 4       87     64     84     97
# 6       83     68     81     93
# 5       81     78    116     95
# 8       79     66    104     84
# 7       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# To combine multiple conditions, you need to place each condition inside parentheses, and use **`&`** for **`and`** and **`|`** for **`or`**.

# %%
# control>100, OR, condA>100
expData[(expData.control>100) | (expData.condA>100)]
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 0      106     80     78     75

# %%
# control<80, AND, condA<80
expData[(expData.control<80) & (expData.condA<80)]
# Out:
#    control  condA  condB  condC
# 2       79     63    120     58
# 8       79     66    104     84
# 7       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# ### Exercise
# **High-risk group**. You are interested in the following subset of the cryotherapy data you generated earlier.
#   * Those who are 30 years or older
#   * And Those whose time since the diagnosis is 8 months or greater
#
# These patients may have a lower chance of success on their cryotherapy treatment. Calculate the success rate (i.e., mean of the column `success`) for this high-risk subset, as well as for the entire data set. ***Hint:*** *You can use the `.mean()` method.*

# %% [markdown]
# # 4. Saving to and loading from a CSV file
# <hr style="height:1px;border:none" />

# %% [markdown]
# You can save a dataframe to a CSV file very easily using **`to_csv`** method.

# %%
expData.to_csv('ExpData_sorted.csv')

# %% [markdown]
# This creates a CSV file called **`ExpData_sorted.csv`** in your current working directory.
# ```
# ,control,condA,condB,condC
# 3,110,73,92,115
# 0,106,80,78,75
# 1,96,70,97,49
# 4,87,64,84,97
# 6,83,68,81,93
# 5,81,78,116,95
# 2,79,63,120,58
# 8,79,66,104,84
# 7,68,45,81,66
# 9,57,56,82,67
# ```
#
# Reading a CSV file is also simple. You can use **`pd.read_csv`** function.

# %%
fileData = pd.read_csv('ExpData_sorted.csv')
fileData
# Out:
#    Unnamed: 0  control  condA  condB  condC
# 0           3      110     73     92    115
# 1           0      106     80     78     75
# 2           1       96     70     97     49
# 3           4       87     64     84     97
# 4           6       83     68     81     93
# 5           5       81     78    116     95
# 6           2       79     63    120     58
# 7           8       79     66    104     84
# 8           7       68     45     81     66
# 9           9       57     56     82     67

# %% [markdown]
# Unfortunately it created a column called **`Unnamed: 0`**, with the original data index (before the data was sorted), in addition to the new index in the first column. You can use the original index by specifying the parameter index_col.

# %%
fileData = pd.read_csv('ExpData_sorted.csv', index_col=0)
fileData
# Out:
#    control  condA  condB  condC
# 3      110     73     92    115
# 0      106     80     78     75
# 1       96     70     97     49
# 4       87     64     84     97
# 6       83     68     81     93
# 5       81     78    116     95
# 2       79     63    120     58
# 8       79     66    104     84
# 7       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# Or, if you want to keep the new index and remove the old index, then you can remove the column by **`drop()`** method.

# %%
fileData = pd.read_csv('ExpData_sorted.csv')
fileData.drop('Unnamed: 0', axis=1, inplace=True)
fileData
# Out:
#    control  condA  condB  condC
# 0      110     73     92    115
# 1      106     80     78     75
# 2       96     70     97     49
# 3       87     64     84     97
# 4       83     68     81     93
# 5       81     78    116     95
# 6       79     63    120     58
# 7       79     66    104     84
# 8       68     45     81     66
# 9       57     56     82     67

# %% [markdown]
# ### Exercise
# 1. **Saving to a CSV file**. Save the cryotherapy dataframe you created earlier (including the column `rankArea`) to a CSV file.

# %% [markdown]
# # 5. Updating data
# <hr style="height:1px;border:none" />

# %% [markdown]
# ***Note: *** *A zip archive file containing all the CSV data files for this lecture is available on GitHub as [`PandasData.zip`](https://github.com/sathayas/PythonClassFall2018/raw/master/pandasExamples/PandaData.zip). Individual CSV files are also available in the [same GitHub repository](https://github.com/sathayas/PythonClassFall2018/tree/master/pandasExamples).*
#
# Let’s go back to the experiment score data, now stored in **`ExpData.csv`**, available on **GitHub**.

# %% [markdown]
# `<LoadExpData.py>`

# %%
import numpy as np
import pandas as pd

expData = pd.read_csv('ExpData.csv', index_col=0)

# %% [markdown]
# Now, we want to see scores for the control condition above 100. To do so, you can do two different approaches.

# %%
expData[expData.control>100].control
# Out:
# 0    106
# 3    110
# Name: control, dtype: int64

# %%
expData.loc[expData.control>100, 'control']
# Out:
# 0    106
# 3    110
# Name: control, dtype: int64

# %% [markdown]
# Now, let's say we want to substitute these scores >100 with 100. You may try

# %%
expData[expData.control>100].control = 100
# Out:
# /usr/lib64/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# And the dataframe wasn't updated.

# %%
expData
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# This time, let's try

# %%
expData.loc[expData.control>100, 'control'] =100
expData
# Out:
#    control  condA  condB  condC
# 0      100     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      100     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# You see that the dataframe has been successfully updated. To view data with a certain condition, you can use both methods of indexing we saw above. However, you need to use **`loc`** or **`iloc`** to update particular values in a dataframe.
#
# If you want to replace scores above 100 with 100 for condition B, you can do

# %%
expData.loc[expData.condB>100, 'condB'] =100
expData
# Out:
#    control  condA  condB  condC
# 0      100     80     78     75
# 1       96     70     97     49
# 2       79     63    100     58
# 3      100     73     92    115
# 4       87     64     84     97
# 5       81     78    100     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    100     84
# 9       57     56     82     67

# %% [markdown]
# ### Exercise
# 1. **Capping `area`**. On the cryotherapy dataframe you generated earlier, observations with `area>200` need to be capped at 200. Write a program to replace appropriate values.

# %% [markdown]
# # 6. Concatenating and merging dataframes
# <hr style="height:1px;border:none" />

# %% [markdown]
# ## Concatenating dataframes
#
# Say, you have two dataframes containing same variables. You can find them in **`ExpData1.csv`** and **`ExpData2.csv`** available on **GitHub**.

# %% [markdown]
# `<ConcatExample.py>`

# %%
# %load ../Codes/pandasExamples/ConcatExample.py
import numpy as np
import pandas as pd

# Two separate dataframes
expData1 = pd.read_csv('ExpData1.csv')
expData1.drop('Unnamed: 0', axis=1, inplace=True)
expData2 = pd.read_csv('ExpData2.csv')
expData2.drop('Unnamed: 0', axis=1, inplace=True)

# concatenating the two
expDataConcat = pd.concat([expData1, expData2], ignore_index=True)
expDataAppend = expData1.append(expData2, ignore_index=True)

# %% [markdown]
# You can verify them.

# %%
expData1
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97

# %%
expData2
# Out:
#    control  condA  condB  condC
# 0       81     78    116     95
# 1       83     68     81     93
# 2       68     45     81     66
# 3       79     66    104     84
# 4       57     56     82     67

# %% [markdown]
# Then you can concatenate them easily in two different ways. The first way involves **`pd.concat`** function to append two data frames.

# %%
expDataConcat = pd.concat([expData1, expData2], ignore_index=True)
expDataConcat
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# The second approach is to append the second dataframe to the first dataframe with **`append()`** method.

# %%
expDataAppend = expData1.append(expData2, ignore_index=True)
expDataAppend
# Out:
#    control  condA  condB  condC
# 0      106     80     78     75
# 1       96     70     97     49
# 2       79     63    120     58
# 3      110     73     92    115
# 4       87     64     84     97
# 5       81     78    116     95
# 6       83     68     81     93
# 7       68     45     81     66
# 8       79     66    104     84
# 9       57     56     82     67

# %% [markdown]
# In both approaches, the parameter **`ignore_index=True`** is specified, so that *concatenated observations are indexed sequentially*.
#
# ### Exercise
# 1.	Try the two concatenation methods above without the parameter **`ignore_index=True`**. Can you tell what happens?

# %% [markdown]
# ## Adding a new observation
#
# To the dataframe **`expData`**, we want to add a new observation, consisting of 4 scores under 4 different conditions.

# %% [markdown]
# `<NewObsExample.py>`

# %%
import numpy as np
import pandas as pd

expData = pd.read_csv('ExpData.csv', index_col=0)

# a new observation to be added
newObs = [55, 88, 86, 70]
expData.loc[len(expData)] = newObs

# %% [markdown]
# The dataframe now includes 11 observations.

# %%
expData
# Out:
#     control  condA  condB  condC
# 0       106     80     78     75
# 1        96     70     97     49
# 2        79     63    120     58
# 3       110     73     92    115
# 4        87     64     84     97
# 5        81     78    116     95
# 6        83     68     81     93
# 7        68     45     81     66
# 8        79     66    104     84
# 9        57     56     82     67
# 10       55     88     86     70

# %% [markdown]
# ### Exercise
# 1. To the dataframe **`expData`**, you want to add 4 additional observations, represented in a 2D array
# ```python
# newRows = np.array([
#        [56, 55, 55, 75],
#        [67, 77, 63, 66],
#        [93, 61, 79, 58],
#        [84, 88, 73, 71]])
# ```
# How do you do this?

# %% [markdown]
# ## Merging two dataframes
#
# You may encounter a scenario where you want to merge two dataframes, each containing a different set of variables, except the subject ID. You want to merge these dataframes so that the observations with the same ID are merged together. Say, you load two dataframes from files **`ExpDataControl.csv`** and **`ExpDataABC.csv`** (available on **GitHub**).

# %% [markdown]
# `<MergeExample.py>`

# %%
import numpy as np
import pandas as pd

# reading two dataframes
expDataControl = pd.read_csv('ExpDataControl.csv',index_col=0)
expDataABC = pd.read_csv('ExpDataABC.csv',index_col=0)

# %% [markdown]
# You can verify their contents.

# %%
expDataControl
# Out:
#    ID  control
# 0   4      110
# 1   1      106
# 2   2       96
# 3   5       87
# 4   7       83
# 5   6       81
# 6   3       79
# 7   9       79
# 8   8       68
# 9  10       57

# %%
expDataABC
# Out:
#    ID  condA  condB  condC
# 0   1     80     78     75
# 1   6     78    116     95
# 2   4     73     92    115
# 3   2     70     97     49
# 4   7     68     81     93
# 5   9     66    104     84
# 6   5     64     84     97
# 7   3     63    120     58
# 8  10     56     82     67
# 9   8     45     81     66

# %% [markdown]
# These dataframes contain different variables. However, there is a variable called ID, indicating which observations belong to which subjects. You can use this information and match observations between two different dataframes with **`pd.merge`** function.

# %%
expData = pd.merge(expDataControl, expDataABC, on='ID')
expData
# Out:
#    ID  control  condA  condB  condC
# 0   4      110     73     92    115
# 1   1      106     80     78     75
# 2   2       96     70     97     49
# 3   5       87     64     84     97
# 4   7       83     68     81     93
# 5   6       81     78    116     95
# 6   3       79     63    120     58
# 7   9       79     66    104     84
# 8   8       68     45     81     66
# 9  10       57     56     82     67

# %% [markdown]
# In some cases, two dataframes may not have the same observations. In that case, there are two different approaches. To demonstrate, let's load a dataframe from file **`ExpDataDE.csv`** (available on **GitHub**).

# %%
# reading another dataframe
expDataDE = pd.read_csv('ExpDataDE.csv',index_col=0)

# %% [markdown]
# In the first approach for merging, you can only keep *complete observations* (i.e., all variables have values).

# %%
pd.merge(expData, expDataDE, on='ID')
# Out:
#    ID  control  condA  condB  condC  condD  condE
# 0   4      110     73     92    115     92     86
# 1   1      106     80     78     75     89     82
# 2   2       96     70     97     49     59     58
# 3   5       87     64     84     97     91     69
# 4   7       83     68     81     93     90     71
# 5   6       81     78    116     95     64     82
# 6  10       57     56     82     67     71     82

# %% [markdown]
# In the second apprach, you want to keep *all observations*. In that case, you need to specify the parameter **`how='outer'`**. If some values are missing, then **`NaN`**s (missing values) are used.

# %%
pd.merge(expData, expDataDE, on='ID', how='outer')
# Out:
#    ID  control  condA  condB  condC  condD  condE
# 0   4      110     73     92    115   92.0   86.0
# 1   1      106     80     78     75   89.0   82.0
# 2   2       96     70     97     49   59.0   58.0
# 3   5       87     64     84     97   91.0   69.0
# 4   7       83     68     81     93   90.0   71.0
# 5   6       81     78    116     95   64.0   82.0
# 6   3       79     63    120     58    NaN    NaN
# 7   9       79     66    104     84    NaN    NaN
# 8   8       68     45     81     66    NaN    NaN
# 9  10       57     56     82     67   71.0   82.0

# %% [markdown]
# # 7. Simple statistics
# <hr style="height:1px;border:none" />

# %% [markdown]
# We have already seen describe method to generate basic stats on a dataframe. You can get individual summary statistics as well, using different methods.

# %% [markdown]
# `<SimpleStats.py>`

# %%
import numpy as np
import pandas as pd

expData = pd.read_csv('ExpData.csv',index_col=0)

# simple descriptive stats
expData.mean()
expData.std()
expData.median()
# Out:
# control    82.0
# condA      67.0
# condB      88.0
# condC      79.5
# dtype: float64

# %%
# correlation
expData.corr()
# Out:
#           control     condA     condB     condC
# control  1.000000  0.739644 -0.043087  0.365258
# condA    0.739644  1.000000  0.244684  0.375087
# condB   -0.043087  0.244684  1.000000 -0.101767
# condC    0.365258  0.375087 -0.101767  1.000000

# %%
# ranking
expData.rank()
expData.control.rank()
# Out:
# 0     9.0
# 1     8.0
# 2     3.5
# 3    10.0
# 4     7.0
# 5     5.0
# 6     6.0
# 7     2.0
# 8     3.5
# 9     1.0
# Name: control, dtype: float64

# %% [markdown]
# # 8. Grouping observations by `groupby`
# <hr style="height:1px;border:none" />

# %% [markdown]
# The file [**`co-est2016-alldata.csv`**](https://github.com/sathayas/PythonClassFall2018/raw/master/pandasExamples/co-est2016-alldata.csv), available on **GitHub**, contains the estimated population of the past 5 years of all counties in 50 states and the District of Columbia.

# %% [markdown]
# `<GroupByExample.py>`

# %%
import numpy as np
import pandas as pd

# loading the county-level census data
ctyData = pd.read_csv('co-est2016-alldata.csv',
                      encoding = 'iso-8859-1')

# getting rid of rows with COUNTY==0
ctyData = ctyData[ctyData["COUNTY"]!=0]

# %% [markdown]
# In this dataframe, the variable **`COUNTY`** is the unique ID for a county in a particular state, and `COUNTY==0` is the state total; so we get rid of those rows so that the rest of the data represent counties. There are 116 variables in total from 3142 counties. Say, you want to summarize the data at the state level, not at the county level. Then you can group the observations by states using the **`groupby`** method.

# %%
# grouping the data by states
stateData = ctyData.groupby('STNAME')

# %% [markdown]
# The variable **`STNAME`** corresponds to different state names. In the newly created dataframe stateData, observations are grouped by states. For a starter, we can see the number of observations (i.e., counties) in each state by using the **`size()`** method.

# %%
stateData.size()
# Out:
# STNAME
# Alabama                  67
# Alaska                   29
# Arizona                  15
# Arkansas                 75
# California               58
# Colorado                 64
# Connecticut               8
# Delaware                  3
# District of Columbia      1
# Florida                  67
# Georgia                 159
# Hawaii                    5
# Idaho                    44
# Illinois                102
# Indiana                  92
# Iowa                     99
# Kansas                  105
# Kentucky                120
# Louisiana                64
# Maine                    16
# Maryland                 24
# Massachusetts            14
# Michigan                 83
# Minnesota                87
# Mississippi              82
# Missouri                115
# Montana                  56
# Nebraska                 93
# Nevada                   17
# New Hampshire            10
# New Jersey               21
# New Mexico               33
# New York                 62
# North Carolina          100
# North Dakota             53
# Ohio                     88
# Oklahoma                 77
# Oregon                   36
# Pennsylvania             67
# Rhode Island              5
# South Carolina           46
# South Dakota             66
# Tennessee                95
# Texas                   254
# Utah                     29
# Vermont                  14
# Virginia                133
# Washington               39
# West Virginia            55
# Wisconsin                72
# Wyoming                  23
# dtype: int64

# %% [markdown]
# You can also calculate various statistics by using different methods. For example,

# %%
stateData.mean()
# Out:
#                       SUMLEV  REGION  DIVISION  STATE      COUNTY  \
# STNAME
# Alabama                 50.0     3.0       6.0    1.0   67.000000
# Alaska                  50.0     4.0       9.0    2.0  149.655172
# Arizona                 50.0     4.0       8.0    4.0   13.866667
# Arkansas                50.0     3.0       7.0    5.0   75.000000
# California              50.0     4.0       9.0    6.0   58.000000
# Colorado                50.0     4.0       8.0    8.0   62.234375
# Connecticut             50.0     1.0       1.0    9.0    8.000000
# Delaware                50.0     3.0       5.0   10.0    3.000000
# District of Columbia    50.0     3.0       5.0   11.0    1.000000
# Florida                 50.0     3.0       5.0   12.0   67.910448
# Georgia                 50.0     3.0       5.0   13.0  161.490566
# Hawaii                  50.0     4.0       9.0   15.0    5.000000
# Idaho                   50.0     4.0       8.0   16.0   44.000000
# Illinois                50.0     2.0       3.0   17.0  102.000000
# Indiana                 50.0     2.0       3.0   18.0   92.000000
# Iowa                    50.0     2.0       4.0   19.0   99.000000
# Kansas                  50.0     2.0       4.0   20.0  105.000000
# Kentucky                50.0     3.0       6.0   21.0  120.000000
# Louisiana               50.0     3.0       7.0   22.0   64.000000
# Maine                   50.0     1.0       1.0   23.0   16.000000
# Maryland                50.0     3.0       5.0   24.0   44.958333
# Colorado                 2.073459     6.379688    10.963051
# Connecticut             -3.754288    -3.630374    -3.385754
# Delaware                 9.897689     9.968580     8.462555
# District of Columbia     7.200899    10.714753     9.458791
# Florida                  9.945010    13.840500    13.743008
# Georgia                 -0.539380     0.604680     0.692759
# Hawaii                   5.205326     3.502945     2.205185
# Idaho                   -1.438994     0.115359     6.614582
# Illinois                -5.319802    -5.879793    -5.444321
# Indiana                 -1.396248    -2.386098    -2.041763
# Iowa                    -1.729279    -2.929597    -2.339604
# Kansas                  -5.402698    -7.308216   -10.046119
# Kentucky                -1.498182    -1.234014    -0.984417
# Louisiana               -3.065618    -3.241292    -3.429179
# Maine                   -0.108862    -0.661258     2.651251
# Maryland                -0.098108     0.464928     1.823154
# Massachusetts            4.621305     1.113132     2.261994
# Michigan                 0.166951    -1.250454    -0.124459
# Minnesota               -2.028824    -1.819702    -1.017783
# Mississippi             -4.712650    -7.100754    -5.188511
# Missouri                -1.762336    -2.509858    -1.104192
# Montana                  0.980659    -0.122279    -0.561168
# Nebraska                -3.608764    -2.588100    -4.300782
# Nevada                  -6.177587    -1.270815    -4.537750
# New Hampshire            5.641876    -0.382125     2.923767
# New Jersey              -1.420816    -2.996813    -2.876590
# New Mexico             -11.618983    -5.868162    -6.522208
# New York                -4.040995    -4.514586    -4.865706
# North Carolina           1.535482     2.269487     4.321940
# North Dakota             6.281857     6.613834   -11.043816
# Ohio                    -1.550425    -2.274841    -1.803142
# Oklahoma                -0.304080    -0.713467    -5.259091
# Oregon                   2.872580     6.383425    13.815550
# Pennsylvania            -1.607090    -2.062832    -2.483428
# Rhode Island             0.914846     2.249671     0.758774
# South Carolina           3.137958     2.713979     2.934129
# South Dakota            -4.365428    -3.611402    -1.741401
# Tennessee                4.059654     3.267060     5.423134
# Texas                    1.181761     5.080276     0.749707
# Utah                     1.800448     3.545630     5.391201
# Vermont                 -1.851891    -2.223758    -2.327726
# Virginia                 0.826367     1.318833     0.440445
# Washington               3.503227     7.058457    12.147411
# West Virginia           -3.278287    -3.421802    -4.690845
# Wisconsin               -0.462629    -1.844098    -0.125276
# Wyoming                 -4.639013    -0.405220    -6.699501
#
# [51 rows x 114 columns]

# %% [markdown]
# However, as you notice, the mean is calculated for all the variables (except **`STNAME`** and string variables). So let's focus on the population from the 2010 census (**`CENSUS2010POP`**).

# %%
stateData.sum().CENSUS2010POP
# Out:
# STNAME
# Alabama                  4779736
# Alaska                    710231
# Arizona                  6392017
# Arkansas                 2915918
# California              37253956
# Colorado                 5029196
# Connecticut              3574097
# Delaware                  897934
# District of Columbia      601723
# Florida                 18801310
# Georgia                  9687653
# Hawaii                   1360301
# Idaho                    1567582
# Illinois                12830632
# Indiana                  6483802
# Iowa                     3046355
# Kansas                   2853118
# Kentucky                 4339367
# Louisiana                4533372
# Maine                    1328361
# Maryland                 5773552
# Massachusetts            6547629
# Michigan                 9883640
# Minnesota                5303925
# Mississippi              2967297
# Missouri                 5988927
# Montana                   989415
# Nebraska                 1826341
# Nevada                   2700551
# New Hampshire            1316470
# New Jersey               8791894
# New Mexico               2059179
# New York                19378102
# North Carolina           9535483
# North Dakota              672591
# Ohio                    11536504
# Oklahoma                 3751351
# Oregon                   3831074
# Pennsylvania            12702379
# Rhode Island             1052567
# South Carolina           4625364
# South Dakota              814180
# Tennessee                6346105
# Texas                   25145561
# Utah                     2763885
# Vermont                   625741
# Virginia                 7994802
# Washington               6724540
# West Virginia            1852994
# Wisconsin                5686986
# Wyoming                   563626
# Name: CENSUS2010POP, dtype: int64

# %% [markdown]
# This shows the population by states. You can use various methods to sort the states by their populations and list top 10. For example,

# %%
stateData.sum().sort_values(by='CENSUS2010POP',
                            ascending=False).CENSUS2010POP.head(10)
# Out:
# STNAME
# California        37253956
# Texas             25145561
# New York          19378102
# Florida           18801310
# Illinois          12830632
# Pennsylvania      12702379
# Ohio              11536504
# Michigan           9883640
# Georgia            9687653
# North Carolina     9535483
# Name: CENSUS2010POP, dtype: int64

# %% [markdown]
# Here, we are using a series of methods to extract this information. We use the **`sum`** method, then the **`sort_values`** method, then selecting the variable **`CENSUS2010POP`**, and finally listing only the top 10 by the **`head`** method. This example shows how we can use multiple methods (in a particular order) to extract information that we want.

# %% [markdown]
# ## Grouping by multiple variables
#
# You can use multiple variables in the **`groupby`** method. In the census data, there is a variable called **`DIVISION`**, a geographical division of the states by the Census Bureau. Namely,
# ```
# 1 = New England
# 2 = Middle Atlantic
# 3 = East North Central
# 4 = West North Central
# 5 = South Atlantic
# 6 = East South Central
# 7 = West South Central
# 8 = Mountain
# 9 = Pacific
# ```
# Now you can group the data by `DIVISION` and `STNAME`.

# %%
# grouping by the divisions and states
divStateData = ctyData.groupby(['DIVISION','STNAME'])

# %% [markdown]
# This produces a grouping with two variables, the division first, then the state.

# %%
divStateData.size()
# Out:
# DIVISION  STNAME
# 1         Connecticut               8
#           Maine                    16
#           Massachusetts            14
#           New Hampshire            10
#           Rhode Island              5
#           Vermont                  14
# 2         New Jersey               21
#           New York                 62
#           Pennsylvania             67
# 3         Illinois                102
#           Indiana                  92
#           Michigan                 83
#           Ohio                     88
#           Wisconsin                72
# 4         Iowa                     99
#           Kansas                  105
#           Minnesota                87
#           Missouri                115
#           Nebraska                 93
#           North Dakota             53
#           South Dakota             66
# 5         Delaware                  3
#           District of Columbia      1
#           Florida                  67
#           Georgia                 159
#           Maryland                 24
#           North Carolina          100
#           South Carolina           46
#           Virginia                133
#           West Virginia            55
# 6         Alabama                  67
#           Kentucky                120
#           Mississippi              82
#           Tennessee                95
# 7         Arkansas                 75
#           Louisiana                64
#           Oklahoma                 77
#           Texas                   254
# 8         Arizona                  15
#           Colorado                 64
#           Idaho                    44
#           Montana                  56
#           Nevada                   17
#           New Mexico               33
#           Utah                     29
#           Wyoming                  23
# 9         Alaska                   29
#           California               58
#           Hawaii                    5
#           Oregon                   36
#           Washington               39
# dtype: int64

# %% [markdown]
# ### Exercise
# 1. **Total population by divisions**. Calculate the total population for each division.
# 2. **Population change by divisions and states**. The variable **`NPOPCHG_2016`** describes the estimated population change between July 2015 and July 2016. Calculate the total population change in each state and tabulate the results by divisions (i.e., group by divisions and states).
